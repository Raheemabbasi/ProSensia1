# %% [markdown]
# <a href="https://colab.research.google.com/github/Raheemabbasi/ProSensia1/blob/main/Untitled17.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
# Load the CSV file into a DataFrame
df = pd.read_csv ('/content/organizations-100.csv')
# Display the first few rows of the DataFrame
print (df.head())
# Out:
#    Index  Organization Id                     Name  \
# 0      1  FAB0d41d5b5d22c              Ferrell LLC
# 1      2  6A7EdDEA9FaDC52  Mckinney, Riley and Day
# 2      3  0bFED1ADAE4bcC1               Hester Ltd
# 3      4  2bFC1Be8a4ce42f           Holder-Sellers
# 4      5  9eE8A6a4Eb96C24              Mayer Group
#
#                           Website           Country  \
# 0              https://price.net/  Papua New Guinea
# 1  http://www.hall-buchanan.info/           Finland
# 2       http://sullivan-reed.com/             China
# 3             https://becker.com/      Turkmenistan
# 4          http://www.brewer.com/         Mauritius
#
#                                       Description  Founded  \
# 0             Horizontal empowering knowledgebase     1990
# 1             User-centric system-worthy leverage     2015
# 2                  Switchable scalable moratorium     1971
# 3  De-engineered systemic artificial intelligence     2004
# ...

# %%
print (df.info())
print (df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Index                100 non-null    int64
#  1   Organization Id      100 non-null    object
#  2   Name                 100 non-null    object
#  3   Website              100 non-null    object
#  4   Country              100 non-null    object
#  5   Description          100 non-null    object
#  6   Founded              100 non-null    int64
#  7   Industry             100 non-null    object
#  8   Number of employees  100 non-null    int64
# dtypes: int64(3), object(6)
# memory usage: 7.2+ KB
# None
#             Index      Founded  Number of employees
# count  100.000000   100.000000           100.000000
# mean    50.500000  1995.410000          4964.860000
# std     29.011492    15.744228          2850.859799
# min      1.000000  1970.000000           236.000000
# ...

# %%
print (df.isnull().sum())
print (df[df.isnull().any(axis=1)])
# Out:
# Index                  0
# Organization Id        0
# Name                   0
# Website                0
# Country                0
# Description            0
# Founded                0
# Industry               0
# Number of employees    0
# dtype: int64
# Empty DataFrame
# Columns: [Index, Organization Id, Name, Website, Country, Description, Founded, Industry, Number of employees]
# Index: []

# %%
df.fillna(df.select_dtypes(include=['number']).mean(), inplace=True)
df.fillna(0, inplace=True)

# %%
print(df['Industry'])

print(df.iloc[0])

print(df[['Website', 'Country', ]].head())
# Out:
# 0                        Plastics
# 1     Glass / Ceramics / Concrete
# 2                   Public Safety
# 3                      Automotive
# 4                  Transportation
#                  ...
# 95                    Photography
# 96              Consumer Services
# 97                Broadcast Media
# 98           Education Management
# 99             Financial Services
# Name: Industry, Length: 100, dtype: object
# Index                                                    1
# Organization Id                            FAB0d41d5b5d22c
# Name                                           Ferrell LLC
# Website                                 https://price.net/
# Country                                   Papua New Guinea
# Description            Horizontal empowering knowledgebase
# Founded                                               1990
# Industry                                          Plastics
# Number of employees                                   3498
# ...

# %%
import matplotlib.pyplot as plt

df.hist(bins=50, figsize=(20, 15))
plt.show()

# %%
import seaborn as sns

#Plot a Scatter Plot
sns.scatterplot(x='Industry',y='Country', data=df)
plt.title('Scatter Plot ofIndustry vs Country')
plt.show()

# %%
import matplotlib.pyplot as plt

#Plot histograms for numerical columns df.hist(bins-50, figsize=(20, 15)) plt.show()

# %%
import seaborn as sns

#Plot a scatter plot sns.scatterplot(x='column1 y="column2', data=df) plt.title('Scatter Plot of Columni vs Column2') plt.show()
